# %% [markdown]
# # 1. Lightgbm

# %% [markdown]
# * 데이터 '와인품질분류.zip'입니다.

# %% [markdown]
# 1. 필요한 라이브러리를 가져옵니다.

# %%
import pandas as pd
import lightgbm as lgbm

# %% [markdown]
# 2. 데이터를 불러옵니다.

# %%
train = pd.read_csv(r"C:\Users\rud92\Downloads\와인품질분류\data\train.csv")
test = pd.read_csv(r"C:\Users\rud92\Downloads\와인품질분류\data\test.csv")
smpl_sub = pd.read_csv(r"C:\Users\rud92\Downloads\와인품질분류\data\sample_submission.csv")

# %%
train.head()
# Out:
#    index  quality  fixed acidity  volatile acidity  citric acid  \
# 0      0        5            5.6             0.695         0.06
# 1      1        5            8.8             0.610         0.14
# 2      2        5            7.9             0.210         0.39
# 3      3        6            7.0             0.210         0.31
# 4      4        6            7.8             0.400         0.26
#
#    residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0             6.8      0.042                  9.0                  84.0
# 1             2.4      0.067                 10.0                  42.0
# 2             2.0      0.057                 21.0                 138.0
# 3             6.0      0.046                 29.0                 108.0
# 4             9.5      0.059                 32.0                 178.0
#
#    density    pH  sulphates  alcohol   type
# 0  0.99432  3.44       0.44     10.2  white
# 1  0.99690  3.19       0.59      9.5    red
# ...

# %%
test.head()
# Out:
#    index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0      0            9.0              0.31         0.48             6.6
# 1      1           13.3              0.43         0.58             1.9
# 2      2            6.5              0.28         0.27             5.2
# 3      3            7.2              0.15         0.39             1.8
# 4      4            6.8              0.26         0.26             2.0
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.043                 11.0                  73.0  0.99380  2.90
# 1      0.070                 15.0                  40.0  1.00040  3.06
# 2      0.040                 44.0                 179.0  0.99480  3.19
# 3      0.043                 21.0                 159.0  0.99480  3.52
# 4      0.019                 23.5                  72.0  0.99041  3.16
#
#    sulphates  alcohol   type
# 0       0.38     11.6  white
# 1       0.49      9.0    red
# ...

# %% [markdown]
# 3. 변수를 변환합니다.

# %%
# type에는 white와 red 두 종류가 있습니다.
# 각각 0,1로 변환합니다.

type_map = {'white': 0, 'red': 1}
train['type'] = train['type'].map(type_map)
test['type'] = test['type'].map(type_map)

# %%
train.head()
# Out:
#    index  quality  fixed acidity  volatile acidity  citric acid  \
# 0      0        5            5.6             0.695         0.06
# 1      1        5            8.8             0.610         0.14
# 2      2        5            7.9             0.210         0.39
# 3      3        6            7.0             0.210         0.31
# 4      4        6            7.8             0.400         0.26
#
#    residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0             6.8      0.042                  9.0                  84.0
# 1             2.4      0.067                 10.0                  42.0
# 2             2.0      0.057                 21.0                 138.0
# 3             6.0      0.046                 29.0                 108.0
# 4             9.5      0.059                 32.0                 178.0
#
#    density    pH  sulphates  alcohol  type
# 0  0.99432  3.44       0.44     10.2     0
# 1  0.99690  3.19       0.59      9.5     1
# ...

# %%
test.head()
# Out:
#    index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0      0            9.0              0.31         0.48             6.6
# 1      1           13.3              0.43         0.58             1.9
# 2      2            6.5              0.28         0.27             5.2
# 3      3            7.2              0.15         0.39             1.8
# 4      4            6.8              0.26         0.26             2.0
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.043                 11.0                  73.0  0.99380  2.90
# 1      0.070                 15.0                  40.0  1.00040  3.06
# 2      0.040                 44.0                 179.0  0.99480  3.19
# 3      0.043                 21.0                 159.0  0.99480  3.52
# 4      0.019                 23.5                  72.0  0.99041  3.16
#
#    sulphates  alcohol  type
# 0       0.38     11.6     0
# 1       0.49      9.0     1
# ...

# %%
# 모델에 입력하기 전 데이터를 정형합니다.
# train_x : train의 'index', 'quality' 피처를 제거하고 저장합니다.
# train_y : train의 'quality'를 저장합니다.
# test_x : test의 'index'를 제거하고 저장합니다.

train_x = train.drop(columns=['index', 'quality'])

train_y = train['quality']

test_x = test.drop(columns=['index'])

# %%
train_x.shape, train_y.shape, test_x.shape
# Out:
# ((5497, 12), (5497,), (1000, 12))

# %%
train_x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            5.6             0.695         0.06             6.8      0.042
# 1            8.8             0.610         0.14             2.4      0.067
# 2            7.9             0.210         0.39             2.0      0.057
# 3            7.0             0.210         0.31             6.0      0.046
# 4            7.8             0.400         0.26             9.5      0.059
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  9.0                  84.0  0.99432  3.44       0.44
# 1                 10.0                  42.0  0.99690  3.19       0.59
# 2                 21.0                 138.0  0.99176  3.05       0.52
# 3                 29.0                 108.0  0.99390  3.26       0.50
# 4                 32.0                 178.0  0.99550  3.04       0.43
#
#    alcohol  type
# 0     10.2     0
# 1      9.5     1
# 2     10.9     0
# ...

# %%
train_y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    6
# Name: quality, dtype: int64

# %%
test_x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            9.0              0.31         0.48             6.6      0.043
# 1           13.3              0.43         0.58             1.9      0.070
# 2            6.5              0.28         0.27             5.2      0.040
# 3            7.2              0.15         0.39             1.8      0.043
# 4            6.8              0.26         0.26             2.0      0.019
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  73.0  0.99380  2.90       0.38
# 1                 15.0                  40.0  1.00040  3.06       0.49
# 2                 44.0                 179.0  0.99480  3.19       0.69
# 3                 21.0                 159.0  0.99480  3.52       0.47
# 4                 23.5                  72.0  0.99041  3.16       0.47
#
#    alcohol  type
# 0     11.6     0
# 1      9.0     1
# 2      9.4     0
# ...

# %% [markdown]
# 4. LightGBM 모델을 생성 및 훈련합니다.

# %%
from lightgbm import LGBMClassifier

lgbm_model = LGBMClassifier(n_estimators=100, learning_rate=0.1, random_state=42)

lgbm_model.fit(train_x, train_y)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025762 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1538
# [LightGBM] [Info] Number of data points in the train set: 5497, number of used features: 12
# [LightGBM] [Info] Start training from score -5.353861
# [LightGBM] [Info] Start training from score -3.386211
# [LightGBM] [Info] Start training from score -1.123105
# [LightGBM] [Info] Start training from score -0.822089
# [LightGBM] [Info] Start training from score -1.783246
# [LightGBM] [Info] Start training from score -3.588077
# [LightGBM] [Info] Start training from score -7.002520
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# 5. 생성한 모델로 예측 데이터를 생성합니다.

# %%
pred = lgbm_model.predict(test_x)

# %% [markdown]
# 6. 제출파일을 생성합니다.

# %%
smpl_sub.head()
# Out:
#    index  quality
# 0      0        0
# 1      1        0
# 2      2        0
# 3      3        0
# 4      4        0

# %%
#서브미션 파일의 quality 변수에 예측값을 대입합니다.
smpl_sub['quality'] = pred

# %%
smpl_sub.head()
# Out:
#    index  quality
# 0      0        5
# 1      1        5
# 2      2        6
# 3      3        5
# 4      4        6

# %%
# csv 파일로 저장합니다.
smpl_sub.to_csv('submission.csv', index=False)

# %% [markdown]
# # 2. XGBoost

# %%
# 데이터 다운로드 링크로 데이터를 코랩에 불러옵니다.

# !wget 'https://bit.ly/3i4n1QB'

import zipfile
with zipfile.ZipFile('3i4n1QB', 'r') as existing_zip:
    existing_zip.extractall('data')
# Out:
# 'wget'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# ------------------------------------------------------------------------
# FileNotFoundError                      Traceback (most recent call last)
# Cell In[46], line 6
#       3 get_ipython().system("wget 'https://bit.ly/3i4n1QB'")
#       5 import zipfile
# ----> 6 with zipfile.ZipFile('3i4n1QB', 'r') as existing_zip:
#       7     existing_zip.extractall('data')
#
# File ~\anaconda3\Lib\zipfile\__init__.py:1331, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1329 while True:
#    1330     try:
# -> 1331         self.fp = io.open(file, filemode)
#    1332     except OSError:
#    1333         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '3i4n1QB'

# %%
import urllib.request
import zipfile

url = 'https://bit.ly/3i4n1QB'
urllib.request.urlretrieve(url, 'wine_data.zip')

with zipfile.ZipFile('wine_data.zip', 'r') as zip_ref:
    zip_ref.extractall('data')

# %%
# 라이브러리 및 데이터 불러오기
import pandas as pd
from xgboost import XGBClassifier

train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

train.drop('index',axis = 1 ,inplace =True)
test.drop('index',axis = 1 ,inplace =True)

# %%
# 데이터 확인

type_map = {'white': 0, 'red': 1}
train['type'] = train['type'].map(type_map)
test['type'] = test['type'].map(type_map)

train.head()
# Out:
#    quality  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        5            5.6             0.695         0.06             6.8
# 1        5            8.8             0.610         0.14             2.4
# 2        5            7.9             0.210         0.39             2.0
# 3        6            7.0             0.210         0.31             6.0
# 4        6            7.8             0.400         0.26             9.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.042                  9.0                  84.0  0.99432  3.44
# 1      0.067                 10.0                  42.0  0.99690  3.19
# 2      0.057                 21.0                 138.0  0.99176  3.05
# 3      0.046                 29.0                 108.0  0.99390  3.26
# 4      0.059                 32.0                 178.0  0.99550  3.04
#
#    sulphates  alcohol  type
# 0       0.44     10.2     0
# 1       0.59      9.5     1
# ...

# %%
# 원핫 인코딩 (pd.get_dummies())

combined = pd.concat([train.drop(columns='quality'), test], axis=0)

combined_encoded = pd.get_dummies(combined)




from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
train_y_encoded = label_encoder.fit_transform(train_y)

# %%
# 모델 정의
from xgboost import XGBClassifier

xgb_model = XGBClassifier(n_estimators=100, learning_rate=0.1, random_state=42)

# %%
# 모델 학습
# X 는 train에서 quality 를 제외한 모든 변수
# y 는 train의 qulity 변수


train_x = combined_encoded.iloc[:len(train), :]
test_x = combined_encoded.iloc[len(train):, :]

train_y = train['quality']

# fit 메소드를 이용해 모델 학습

xgb_model.fit(train_x, train_y_encoded)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
# predict 메소드와 원핫 인코딩한 test 데이터를 이용해 품질 예측

pred = xgb_model.predict(test_x)

# %%
# sample_submission.csv 파일을 불러와 예측된 값으로 채워 주기

smpl_sub['quality'] = pred

# %%
# 정답파일 내보내기
smpl_sub.to_csv('xgb_pred.csv',index = False)

# %% [markdown]
# # 3. 보팅

# %%
# 데이터 다운로드 링크로 데이터를 코랩에 불러옵니다.

# !wget 'https://bit.ly/3i4n1QB'

import zipfile
with zipfile.ZipFile('3i4n1QB', 'r') as existing_zip:
    existing_zip.extractall('data')
# Out:
# 'wget'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# ------------------------------------------------------------------------
# FileNotFoundError                      Traceback (most recent call last)
# Cell In[78], line 6
#       3 get_ipython().system("wget 'https://bit.ly/3i4n1QB'")
#       5 import zipfile
# ----> 6 with zipfile.ZipFile('3i4n1QB', 'r') as existing_zip:
#       7     existing_zip.extractall('data')
#
# File ~\anaconda3\Lib\zipfile\__init__.py:1331, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1329 while True:
#    1330     try:
# -> 1331         self.fp = io.open(file, filemode)
#    1332     except OSError:
#    1333         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '3i4n1QB'

# %%
import urllib.request
import zipfile

url = 'https://bit.ly/3i4n1QB'

output_file = 'wine_data.zip'

urllib.request.urlretrieve(url, output_file)

with zipfile.ZipFile(output_file, 'r') as zip_ref:
    zip_ref.extractall('data')

# %%
# 라이브러리 및 데이터 불러오기
import pandas as pd
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier

train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

train.drop('index',axis = 1 ,inplace =True)
test.drop('index',axis = 1 ,inplace =True)

# %%
# 데이터 확인
train.head()
# Out:
#    quality  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        5            5.6             0.695         0.06             6.8
# 1        5            8.8             0.610         0.14             2.4
# 2        5            7.9             0.210         0.39             2.0
# 3        6            7.0             0.210         0.31             6.0
# 4        6            7.8             0.400         0.26             9.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.042                  9.0                  84.0  0.99432  3.44
# 1      0.067                 10.0                  42.0  0.99690  3.19
# 2      0.057                 21.0                 138.0  0.99176  3.05
# 3      0.046                 29.0                 108.0  0.99390  3.26
# 4      0.059                 32.0                 178.0  0.99550  3.04
#
#    sulphates  alcohol   type
# 0       0.44     10.2  white
# 1       0.59      9.5    red
# ...

# %%
test.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            9.0              0.31         0.48             6.6      0.043
# 1           13.3              0.43         0.58             1.9      0.070
# 2            6.5              0.28         0.27             5.2      0.040
# 3            7.2              0.15         0.39             1.8      0.043
# 4            6.8              0.26         0.26             2.0      0.019
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  73.0  0.99380  2.90       0.38
# 1                 15.0                  40.0  1.00040  3.06       0.49
# 2                 44.0                 179.0  0.99480  3.19       0.69
# 3                 21.0                 159.0  0.99480  3.52       0.47
# 4                 23.5                  72.0  0.99041  3.16       0.47
#
#    alcohol   type
# 0     11.6  white
# 1      9.0    red
# 2      9.4  white
# ...

# %%
# 원핫 인코딩 (pd.get_dummies())

type_map = {'white': 0, 'red': 1}
train['type'] = train['type'].map(type_map)
test['type'] = test['type'].map(type_map)


combined = pd.concat([train.drop(columns='quality'), test], axis=0)

combined_encoded = pd.get_dummies(combined)




from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
train_y_encoded = label_encoder.fit_transform(train_y)

# %%
# 모델 정의 (LightGBM, XGBoost, Random Forest)

lgbm_model = LGBMClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
xgb_model = XGBClassifier(n_estimators=100, learning_rate=0.1, random_state=42, use_label_encoder=False, eval_metric='mlogloss')
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# VotingClassifier 정의
voting_model = VotingClassifier(
    estimators=[
        ('lgbm', lgbm_model),
        ('xgb', xgb_model),
        ('rf', rf_model)
    ],
    voting='hard'
)

# %%
# 모델 학습
voting_model.fit(train_x, train_y_encoded)

# X 는 train에서 quality 를 제외한 모든 변수
# y 는 train의 qulity 변수

train_x = combined_encoded.iloc[:len(train), :]
test_x = combined_encoded.iloc[len(train):, :]

train_y = train['quality']


# fit 메소드를 이용해 모델 학습
pred_encoded = voting_model.predict(test_x)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000614 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1538
# [LightGBM] [Info] Number of data points in the train set: 5497, number of used features: 12
# [LightGBM] [Info] Start training from score -5.353861
# [LightGBM] [Info] Start training from score -3.386211
# [LightGBM] [Info] Start training from score -1.123105
# [LightGBM] [Info] Start training from score -0.822089
# [LightGBM] [Info] Start training from score -1.783246
# [LightGBM] [Info] Start training from score -3.588077
# [LightGBM] [Info] Start training from score -7.002520
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
# predict 메소드와 원핫 인코딩한 테스트 데이터를 이용해 품질 예측
pred = label_encoder.inverse_transform(pred_encoded)
