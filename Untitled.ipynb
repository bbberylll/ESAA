# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()       ## 이게 뭘까

# %matplotlib inline

pd.options.mode.chained_assignment = None

# %%
from subprocess import check_output    ## 이건 무슨 코드?? 
import os

##print(check_output(["dir", "../1st_input"], shell=True).decode("utf8"))
## 위의 코드는 계속 오류가 생김... window의 문제인가??

print(os.listdir("../1st_input"))

## "./input"은 같은 폴더 내에 있는 경우
## "../input"은 부모 폴더 내에 input이 있어야 함
# Out:
# ['aisles.csv', 'departments.csv', 'orders.csv', 'order_products__prior.csv', 'order_products__train.csv', 'products.csv', 'sample_submission.csv']

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\rud92\0.ESAA\kaggle\1st_kaggle

# %%
order_products_train_df = pd.read_csv("../1st_input/order_products__train.csv")
order_products_prior_df = pd.read_csv("../1st_input/order_products__prior.csv")
orders_df = pd.read_csv("../1st_input/orders.csv")
products_df = pd.read_csv("../1st_input/products.csv")
aisles_df = pd.read_csv("../1st_input/aisles.csv")
departments_df = pd.read_csv("../1st_input/departments.csv")

# %%
orders_df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
order_products_prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
order_products_train_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
cnt_srs = orders_df.eval_set.value_counts()

plt.figure(figsize=(12,8))
sns.barplot(x=cnt_srs.index, y=cnt_srs.values, alpha=0.8, color=color[1])
##과거랑 달리 x=, y= 이걸 명시해줘야 오류가 나지 않음 

plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Eval set type', fontsize=12)
plt.title('Count of rows in each dataset', fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
def get_unique_count(x):
    return len(np.unique(x))


cnt_srs = orders_df.groupby("eval_set")["user_id"].aggregate(get_unique_count)
cnt_srs
# Out:
# eval_set
# prior    206209
# test      75000
# train    131209
# Name: user_id, dtype: int64

# %%
cnt_srs = orders_df.groupby("user_id")["order_number"].aggregate(np.max).reset_index()
cnt_srs = cnt_srs.order_number.value_counts()

plt.figure(figsize=(12,8))
sns.barplot(x=cnt_srs.index, y=cnt_srs.values, alpha=0.8, color=color[2])
plt.ylabel("Number of Occurences", fontsize=12)
plt.xlabel("Maximum order number", fontsize=12)
plt.xticks(rotation=90)
##plt.xticks(rotation='vertical')   ## 이것도 가능! 
plt.show()
# Out:
# C:\Users\rud92\AppData\Local\Temp\ipykernel_16680\3193033973.py:1: FutureWarning: The provided callable <function max at 0x000002397628DDA0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   cnt_srs = orders_df.groupby("user_id")["order_number"].aggregate(np.max).reset_index()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x="order_dow", data=orders_df, color=color[0])
plt.ylabel('Count', fontsize=12)
plt.xlabel('Day of week', fontsize=12)
plt.xticks(rotation=90)
plt.title('Frequency of order by week day', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x="order_hour_of_day", data=orders_df, color=color[1])
plt.ylabel('Count', fontsize=12)
plt.xlabel('Hour of day', fontsize=12)
plt.xticks(rotation=90)
plt.title("Frequency of order by hour of day", fontsize=15)
plt.show()

# %%
grouped_df = orders_df.groupby(["order_dow", "order_hour_of_day"])["order_number"].aggregate("count").reset_index()
grouped_df = grouped_df.pivot(index='order_dow', columns='order_hour_of_day', values='order_number')
## 데이터 축을 바탕으로 데이터 재정렬
## 과거와 달리 index, columns, values 라는 파라미터를 넣어줘야 한다! 

plt.figure(figsize=(12,6))
sns.heatmap(grouped_df, cmap='Blues')
## 빈도가 높을 수록 연한색으로 나와서 이거 변경 --> cmap = 'Blues'라는 옵션 추가
plt.title('Frequency of Day of week Vs Hour of day')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x="days_since_prior_order", data=orders_df, color=color[3])
plt.ylabel('Count', fontsize=12)
plt.xlabel('Days since prior order', fontsize=12)
plt.xticks(rotation=90)
plt.title("Frequency distribution by days since prior order", fontsize=15)
plt.show()

# %%
order_products_prior_df.reordered.sum()/order_products_prior_df.shape[0]
# Out:
# 0.5896974667922161

# %%
order_products_train_df.reordered.sum()/order_products_train_df.shape[0]
# Out:
# 0.5985944127509629

# %%
grouped_df = order_products_prior_df.groupby("order_id")["reordered"].aggregate("sum").reset_index()

##grouped_df["reordered"].ix[grouped_df["reordered"]>1] = 1 --> 
grouped_df.loc[grouped_df["reordered"] > 1, "reordered"] = 1

grouped_df.reordered.value_counts()/grouped_df.shape[0]
##ix 함수??? --> 최근 pd에서는 사라짐  loc를 이용하는게 더 좋다!
# Out:
# reordered
# 1    0.879151
# 0    0.120849
# Name: count, dtype: float64

# %%
grouped_df = order_products_train_df.groupby("order_id")["reordered"].aggregate("sum").reset_index()
grouped_df.loc[grouped_df["reordered"]>1, "reordered"] = 1
grouped_df.reordered.value_counts()/grouped_df.shape[0]
# Out:
# reordered
# 1    0.93444
# 0    0.06556
# Name: count, dtype: float64

# %%
grouped_df = order_products_train_df.groupby("order_id")["add_to_cart_order"].aggregate("max").reset_index()
cnt_srs = grouped_df.add_to_cart_order.value_counts()

plt.figure(figsize=(12,8))
sns.barplot(x=cnt_srs.index, y=cnt_srs.values, alpha=0.8)
plt.ylabel('Number of Occurences', fontsize=12)
plt.xlabel('Number of products in the given order', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
products_df.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
aisles_df.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
departments_df.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
order_products_prior_df = pd.merge(order_products_prior_df, products_df, on='product_id', how='left')

## merge 함수 : 합병 함수 (왼쪽, 오른쪽, on = 기준 칼럼, how=왼,오 중 어딜 기준으로?)
## 이름이 같은 칼럼이 있어서 문제가 발생 --> 드랍하거나, 드랍할 수 없다면 접미사 suffixes=()를 설정

order_products_prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0         2       33120                  1          1     Organic Egg Whites
# 1         2       28985                  2          1  Michigan Organic Kale
# 2         2        9327                  3          0          Garlic Powder
# 3         2       45918                  4          1         Coconut Butter
# 4         2       30035                  5          0      Natural Sweetener
#
#    aisle_id  department_id
# 0        86             16
# 1        83              4
# 2       104             13
# 3        19             13
# 4        17             13

# %%
order_products_prior_df = pd.merge(order_products_prior_df, aisles_df, on='aisle_id', how='left')

order_products_prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0         2       33120                  1          1     Organic Egg Whites
# 1         2       28985                  2          1  Michigan Organic Kale
# 2         2        9327                  3          0          Garlic Powder
# 3         2       45918                  4          1         Coconut Butter
# 4         2       30035                  5          0      Natural Sweetener
#
#    aisle_id  department_id               aisle
# 0        86             16                eggs
# 1        83              4    fresh vegetables
# 2       104             13   spices seasonings
# 3        19             13       oils vinegars
# 4        17             13  baking ingredients

# %%
order_products_prior_df = pd.merge(order_products_prior_df, departments_df, on="department_id", how="left")
order_products_prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0         2       33120                  1          1     Organic Egg Whites
# 1         2       28985                  2          1  Michigan Organic Kale
# 2         2        9327                  3          0          Garlic Powder
# 3         2       45918                  4          1         Coconut Butter
# 4         2       30035                  5          0      Natural Sweetener
#
#    aisle_id  department_id               aisle  department
# 0        86             16                eggs  dairy eggs
# 1        83              4    fresh vegetables     produce
# 2       104             13   spices seasonings      pantry
# 3        19             13       oils vinegars      pantry
# 4        17             13  baking ingredients      pantry

# %%
cnt_srs = order_products_prior_df['product_name'].value_counts().reset_index().head(20)

cnt_srs.columns = ['product_name', 'frequency_count']
## 칼럼 이름 설정

cnt_srs
# Out:
#                 product_name  frequency_count
# 0                     Banana           472565
# 1     Bag of Organic Bananas           379450
# 2       Organic Strawberries           264683
# 3       Organic Baby Spinach           241921
# 4       Organic Hass Avocado           213584
# 5            Organic Avocado           176815
# 6                Large Lemon           152657
# 7               Strawberries           142951
# 8                      Limes           140627
# 9         Organic Whole Milk           137905
# 10       Organic Raspberries           137057
# 11      Organic Yellow Onion           113426
# 12            Organic Garlic           109778
# 13          Organic Zucchini           104823
# 14       Organic Blueberries           100060
# 15            Cucumber Kirby            97315
# 16        Organic Fuji Apple            89632
# 17             Organic Lemon            87746
# 18  Apple Honeycrisp Organic            85020
# ...

# %%
cnt_srs = order_products_prior_df['aisle'].value_counts().head(20)

plt.figure(figsize=(12,8))
sns.barplot(x=cnt_srs.index, y=cnt_srs.values, alpha=0.8, color=color[5])

plt.ylabel('Number of Occurences', fontsize=12)
plt.xlabel('Aisle', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,8))
temp_series = order_products_prior_df['department'].value_counts()
labels = (np.array(temp_series.index))
sizes= (np.array((temp_series / temp_series.sum())*100))
plt.pie(sizes, labels=labels, autopct = '%1.1f%%', startangle=200)
plt.title("Departments distribution", fontsize=15)
plt.show()

##  파이 그리는 법 정리해두기

# %%
grouped_df = order_products_prior_df.groupby(["department"])["reordered"].aggregate("mean").reset_index()

plt.figure(figsize=(12,8))
sns.pointplot(x=grouped_df["department"].values, y=grouped_df["reordered"].values, alpha=0.8, color=color[2])
plt.ylabel("Reorder ratio", fontsize=12)
plt.xlabel("Department", fontsize=12)
plt.title("Department wise reorder ratio", fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %%
grouped_df = order_products_prior_df.groupby(["department_id", "aisle"])["reordered"].aggregate("mean").reset_index()

fig, ax = plt.subplots(figsize=(12,20))
ax.scatter(grouped_df.reordered.values, grouped_df.department_id.values)

for i, txt in enumerate(grouped_df.aisle.values):
    ax.annotate(txt, (grouped_df.reordered.values[i], grouped_df.department_id.values[i]), rotation=45, ha="center", va="center", color='green')

plt.xlabel("Reorder Ratio")
plt.ylabel("department_id")
plt.title("Reorder ration of different aisles", fontsize=15)
plt.show()

# %%
order_products_prior_df["add_to_cart_order_mod"] = order_products_prior_df["add_to_cart_order"].copy()
order_products_prior_df.loc[order_products_prior_df["add_to_cart_order_mod"]>70, "add_to_cart_order_mod"] =70

grouped_df = order_products_prior_df.groupby(["add_to_cart_order_mod"])["reordered"].aggregate("mean").reset_index()

plt.figure(figsize=(12,8))
sns.pointplot(x=grouped_df["add_to_cart_order_mod"].values, y=grouped_df["reordered"].values, alpha=0.8, color=color[2])

plt.ylabel("Reorder ratio", fontsize=12)
plt.xlabel("Add to cart order", fontsize=12)
plt.title("Add to cart order - Reorder ratio", fontsize=15)
plt.xticks(roatation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 12
#      10 plt.xlabel("Add to cart order", fontsize=12)
#      11 plt.title("Add to cart order - Reorder ratio", fontsize=15)
# ---> 12 plt.xticks(roatation=90)
#      13 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2066, in xticks(ticks, labels, minor, **kwargs)
#    2064     labels_out = ax.get_xticklabels(minor=minor)
#    2065     for l in labels_out:
# -> 2066         l._internal_update(kwargs)
#    2067 else:
#    2068     labels_out = ax.set_xticklabels(labels, minor=minor, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
# ...

# %%
order_products_train_df = pd.merge(order_products_train_df, orders_df, on='order_id', how='left')
grouped_df = order_products_train_df.groupby(["order_dow"])["reordered"].aggregate("mean").reset_index()

plt.figure(figsize=(12,8))
sns.barplot(x=grouped_df['order_dow'].values, y=grouped_df["reordered"].values, alpha=0.8, color=color[3])

plt.ylabel("Reorder ratio", fontsize=12)
plt.xlabel("Day of week", fontsize=12)
plt.title("Reorder ratio across day of week", fontsize=15)
plt.xticks(rotation=90)
plt.ylim(0.5, 0.7)
plt.show()

# %%
grouped_df = order_products_train_df.groupby(["order_hour_of_day"])["reordered"].aggregate("mean").reset_index()

plt.figure(figsize=(12,8))
sns.barplot(x=grouped_df["order_hour_of_day"].values, y=grouped_df["reordered"].values, alpha=0.8, color=color[4])
plt.ylabel("Reorder ratio", fontsize=12)
plt.xlabel("Hour of day", fontsize=12)
plt.title("Reorder ratio across hour of day", fontsize=15)
plt.xticks(rotation=90)
plt.ylim(0.5, 0.7)
plt.show()

# %%
grouped_df = order_products_train_df.groupby(["order_dow", "order_hour_of_day"])["reordered"].aggregate("mean").reset_index()
grouped_df = grouped_df.pivot(index="order_dow", columns="order_hour_of_day", values="reordered")

plt.figure(figsize=(12,6))
sns.heatmap(grouped_df)
plt.title("Reorder ratio of Day of week VS Hour of day")
plt.show()

# %% [markdown]
# ### 새로운 그림

# %%
grouped = order_products_prior_df.groupby(['aisle_id', 'department']).size().reset_index(name='count')
grouped.head(100)
# Out:
#     aisle_id       department    count
# 0          1             deli    71928
# 1          2       dairy eggs    82491
# 2          3           snacks   456386
# 3          4  dry goods pasta   200687
# 4          5           pantry    62510
# 5          6            other    36291
# 6          7     meat seafood    33865
# 7          8           bakery    34871
# 8          9  dry goods pasta   218387
# 9         10        household     9172
# 10        11    personal care    26061
# 11        12  dry goods pasta    36727
# 12        13             deli    99032
# 13        14             deli   129474
# 14        15     meat seafood    20931
# 15        16          produce   377741
# 16        17           pantry   326692
# 17        18             bulk    17368
# 18        19           pantry   245466
# 19        20    personal care    63749
# 20        21       dairy eggs   979763
# 21        22    personal care    32013
# 22        23           snacks   163524
# ...

# %%
print(aisles_df['aisle'].value_counts().sum())

print(departments_df.value_counts().sum())
# Out:
# 134
# 21

# %%
heat_map_data = order_products_prior_df.groupby(['aisle','department'])['reordered'].mean().reset_index()
heatmap_pivot = heat_map_data.pivot(index='department', columns='aisle', values='reordered')

print(heat_map_data)
# Out:
#                              aisle     department  reordered
# 0           air fresheners candles      household   0.309052
# 1                      asian foods  international   0.351132
# 2                 baby accessories         babies   0.550980
# 3              baby bath body care         babies   0.295770
# 4                baby food formula         babies   0.590259
# ..                             ...            ...        ...
# 129              trash bags liners      household   0.335744
# 130           vitamins supplements  personal care   0.311503
# 131  water seltzer sparkling water      beverages   0.729593
# 132                    white wines        alcohol   0.630081
# 133                         yogurt     dairy eggs   0.686489
#
# [134 rows x 3 columns]

# %%
plt.figure(figsize=(12,8))
sns.heatmap(heatmap_pivot, cmap="Blues", annot=True)
plt.title("Recorded Rate by Department & Aisle")
plt.show()

# %% [markdown]
# department와 aisle 별로 재주문율이 어느 정도 나오는지 확인하는 히트맵을 그렸다.
# groupby를 할 때 mean 이 아니라 sum을 이용하려 했으나 크기가 너무 크게 나와 평균을 반영하는 것이 적절할 것으로 보여 변경했다.
#
# 높은 재주문율을 가진 aisle/department 조합은 일상적으로 자주 구매하는 달걀, 우유, 과일, 생수 등의 상품이고, 낮은 재주문율을 가진 조합은 특정 향신료, 일회성 행사용 상품인 경우가 많다.
# 매대와 department 정보를 동시에 확인할 수 있는 그림이다.

# %% [markdown]
# ### 개념
#
# 1) plt.xticks(rotation='vertical')   ## 이것도 가능!
#
# 2) 추가된 파라미터
# sns.barplot은 과거랑 달리 x=, y= 이걸 명시해줘야 오류가 나지 않음
# sns.countplot(x=, data=, color=) 이것도 명시해줘야 오류가 나지 않음
# df.pivot(index=, columns=, values=) 데이터 축을 바탕으로 데이터를 재정렬 & 파라미터를 명시해줘야 함!
#
# 3) 새로운 함수 & 궁금했던 내용
#    1. 히트맵 색깔 스펙트럼 변경
#       sns.heatmap(grouped_df, cmap='Blues')
#         - 빈도가 높을 수록 연한색으로 나와서 이거 변경 --> cmap = 'Blues'라는 옵션 추가
#
#     2. ix는 현재는 사용되지 않고, loc 함수로 대체한다.
#
#     3. pd.merge()
#         - merge 함수 : 합병 함수 (왼쪽, 오른쪽, on = 기준 칼럼, how=왼,오 중 어딜 기준으로?)
#         - 이름이 같은 칼럼이 있어서 문제가 발생 --> 드랍하거나, 드랍할 수 없다면 접미사 suffixes=()를 설정
#
#     4. sns.pointplot(x=, y=, alpha=0.8, color=)
